# %% [markdown]
# 1.1 Load the Dataset & Check Basic Information
#
# Here’s the Python code to:
#
# - Load the dataset
# - Check the first few rows
# - Display column names and data types

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = "/Users/angad/Documents/vehicale sales/AI-powered-vehicle-demand-forecasting/car_prices.csv"  # Change this to your actual file path

df = pd.read_csv(file_path)  # Ensure 'Date' is parsed correctly

# Display basic info
print("Dataset Info:")
print(df.info())

# Check the first few rows
print("\nFirst 5 Rows:")
print(df.head())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# ...

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
df.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
df.describe(include="O")
# Out:
#           make   model    trim    body transmission        vin   state  \
# count   548536  548438  548186  545642       493485     558833  558837
# unique      96     973    1963      87            4     550297      64
# top       Ford  Altima    Base   Sedan    automatic  automatic      fl
# freq     93554   19349   55817  199437       475915         22   82945
#
#          color interior              seller  \
# count   558088   558088              558837
# unique      46       17               14263
# top      black    black  nissan-infiniti lt
# freq    110970   244329               19693
#
#                                        saledate
# count                                    558825
# unique                                     3766
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       5334

# %%
df.shape
# Out:
# (558837, 16)

# %%
# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df['make']=df['make'].fillna(value='No_Value')
df[df['make']=='No_Value']
# Out:
#         year      make model trim body transmission                vin state  \
# 742     2012  No_Value   NaN  NaN  NaN    automatic  wbakb8c51cc964387    ca
# 747     2012  No_Value   NaN  NaN  NaN    automatic  wbakb8c53cc964410    ca
# 766     2012  No_Value   NaN  NaN  NaN    automatic  wbakb8c54cc964089    ca
# 798     2012  No_Value   NaN  NaN  NaN    automatic  wbakb8c59cc448049    ca
# 803     2012  No_Value   NaN  NaN  NaN    automatic  wbakb8c58cc962863    ca
# ...      ...       ...   ...  ...  ...          ...                ...   ...
# 558545  2000  No_Value   NaN  NaN  NaN    automatic  4n2xn11txyd844711    ma
# 558617  2007  No_Value   NaN  NaN  NaN    automatic  jtjbt20x770129305    pa
# 558736  2011  No_Value   NaN  NaN  NaN    automatic  4a4jn2as6be029938    nv
# 558773  2005  No_Value   NaN  NaN  NaN    automatic  1g1yy24u355116011    tx
# 558776  2013  No_Value   NaN  NaN  NaN    automatic  zam39nka2d0068288    ga
#
# ...

# %%
df['make'].unique()
# Out:
# array(['Kia', 'BMW', 'Volvo', 'Nissan', 'Chevrolet', 'Audi', 'Ford',
#        'Hyundai', 'Buick', 'Cadillac', 'Acura', 'Lexus', 'Infiniti',
#        'Jeep', 'Mercedes-Benz', 'Mitsubishi', 'Mazda', 'MINI',
#        'Land Rover', 'Lincoln', 'lincoln', 'Jaguar', 'Volkswagen',
#        'Toyota', 'Subaru', 'Scion', 'Porsche', 'No_Value', 'bmw', 'Dodge',
#        'FIAT', 'Chrysler', 'ford', 'Ferrari', 'Honda', 'GMC',
#        'mitsubishi', 'Ram', 'smart', 'chevrolet', 'Bentley', 'chrysler',
#        'pontiac', 'Pontiac', 'Saturn', 'Maserati', 'Mercury', 'HUMMER',
#        'landrover', 'cadillac', 'land rover', 'mercedes', 'mazda',
#        'toyota', 'lexus', 'gmc truck', 'honda', 'nissan', 'porsche',
#        'Saab', 'Suzuki', 'dodge', 'subaru', 'Oldsmobile', 'oldsmobile',
#        'hyundai', 'jeep', 'Isuzu', 'dodge tk', 'Geo', 'acura',
#        'volkswagen', 'suzuki', 'kia', 'audi', 'Rolls-Royce', 'gmc',
#        'maserati', 'mazda tk', 'mercury', 'buick', 'hyundai tk',
# ...

# %%
df['make']=df['make'].str.upper()
df['make'].unique()
# Out:
# array(['KIA', 'BMW', 'VOLVO', 'NISSAN', 'CHEVROLET', 'AUDI', 'FORD',
#        'HYUNDAI', 'BUICK', 'CADILLAC', 'ACURA', 'LEXUS', 'INFINITI',
#        'JEEP', 'MERCEDES-BENZ', 'MITSUBISHI', 'MAZDA', 'MINI',
#        'LAND ROVER', 'LINCOLN', 'JAGUAR', 'VOLKSWAGEN', 'TOYOTA',
#        'SUBARU', 'SCION', 'PORSCHE', 'NO_VALUE', 'DODGE', 'FIAT',
#        'CHRYSLER', 'FERRARI', 'HONDA', 'GMC', 'RAM', 'SMART', 'BENTLEY',
#        'PONTIAC', 'SATURN', 'MASERATI', 'MERCURY', 'HUMMER', 'LANDROVER',
#        'MERCEDES', 'GMC TRUCK', 'SAAB', 'SUZUKI', 'OLDSMOBILE', 'ISUZU',
#        'DODGE TK', 'GEO', 'ROLLS-ROYCE', 'MAZDA TK', 'HYUNDAI TK',
#        'MERCEDES-B', 'VW', 'DAEWOO', 'CHEV TRUCK', 'FORD TK', 'PLYMOUTH',
#        'FORD TRUCK', 'TESLA', 'AIRSTREAM', 'DOT', 'ASTON MARTIN',
#        'FISKER', 'LAMBORGHINI', 'LOTUS'], dtype=object)

# %%
df['model']=df['model'].str.upper()
df['model'].unique()
# Out:
# array(['SORENTO', '3 SERIES', 'S60', '6 SERIES GRAN COUPE', 'ALTIMA',
#        'M5', 'CRUZE', 'A4', 'CAMARO', 'A6', 'OPTIMA', 'FUSION', 'SONATA',
#        'Q5', '6 SERIES', 'IMPALA', '5 SERIES', 'A3', 'XC70', 'X5', 'SQ5',
#        'S5', 'VERANO', 'SUBURBAN', 'ELR', 'V60', 'X6', 'ILX', 'K900',
#        'MALIBU', 'RX 350', 'VERSA', 'ELANTRA', 'VERSA NOTE', 'A8', 'X1',
#        nan, 'ENCLAVE', 'TTS', '4 SERIES', 'SILVERADO 2500HD', 'MDX',
#        'SILVERADO 1500', 'SRX', 'G COUPE', 'G SEDAN', 'FX', 'SANTA FE',
#        'GENESIS', 'EQUUS', 'SONATA HYBRID', 'ACCENT', 'VELOSTER',
#        'ELANTRA COUPE', 'AZERA', 'TUCSON', 'GENESIS COUPE', 'WRANGLER',
#        'S-CLASS', 'GS 350', 'OUTLANDER', 'C-CLASS', 'MAZDA2', 'RIO', 'M',
#        '370Z', 'SOUL', 'OUTLANDER SPORT', 'SLK-CLASS', 'ES 350',
#        'E-CLASS', 'MAZDA3', 'COOPER CLUBMAN', 'COOPER', 'CX-9', 'FORTE',
#        'COMPASS', 'JX', 'RX 450H', 'LR4', 'MAZDA5', 'RANGE ROVER EVOQUE',
# ...

# %%
df.nunique()
# Out:
# year                34
# make                67
# model              851
# trim              1963
# body                87
# transmission         4
# vin             550297
# state               64
# condition           41
# odometer        172278
# color               46
# interior            17
# seller           14263
# mmr               1101
# sellingprice      1887
# saledate          3766
# dtype: int64

# %%
df['vin'][df['make']=='BMW']
# Out:
# 2         wba3c1c51ek116351
# 4         wba6b2c57ed129731
# 6         wbsfv9c51ed593089
# 19        wbayp9c53ed169260
# 21        wba5a5c51ed501631
#                 ...
# 558781    wbavb335x6ks34097
# 558783    wbaev53413km28443
# 558808    wbaun93588vf56134
# 558831    wbafr1c53bc744672
# 558834    5uxzw0c58cl668465
# Name: vin, Length: 20793, dtype: object

# %%
df['vin'][df['make']=='FORD']
# Out:
# 12        3fa6p0hdxfr145753
# 94        3fa6p0h7xfr151689
# 938       1fbss3bl8cdb20464
# 939       1fmcu0eg0ckb55384
# 941       2fmdk3jc5cba41602
#                 ...
# 558799    1fahp3k24cl249912
# 558803    1fafp24197g115952
# 558817    2fmhk6cc1cbd17905
# 558821    1fmcu9d78ckc84074
# 558836    1ftfw1et2eke87277
# Name: vin, Length: 93997, dtype: object

# %%
df['vin'][df['make']=='KIA']
# Out:
# 0         5xyktca69fg566472
# 1         5xyktca69fg561319
# 11        5xxgm4a73fg353538
# 13        5xyktca66fg561407
# 32        5xyktca60fg565226
#                 ...
# 558724    knafu4a27d5718608
# 558782    5xxgr4a76eg266054
# 558800    kndjt2a57c7424577
# 558819    5xxgn4a74cg032147
# 558832    knalw4d4xf6019304
# Name: vin, Length: 18084, dtype: object

# %%
df['vin'][df['make']=='AUDI']
# Out:
# 8         wauffafl3en030343
# 10        wauhgafc0en062916
# 17        wa1lfafpxea085074
# 23        wauacgff7f1002327
# 31        wa1cgafp4ea030312
#                 ...
# 558673    waubfafl4fn012904
# 558674    waubfafl3fn013218
# 558730    wa1dkafp8ca047128
# 558753    wauaf78e08a063694
# 558824    waucgafh6dn005382
# Name: vin, Length: 5877, dtype: object

# %%
df['vin'][df['make']=='VOLVO']
# Out:
# 3         yv1612tb4f1310987
# 26        yv4902nb3f1198103
# 27        yv4902nb3f1196951
# 43        yv1612sb9f1202043
# 46        yv1612sb1f1201503
#                 ...
# 558528    yv4902dz6c2346734
# 558530    yv4940dz0b2218495
# 558644    yv1cz59h841119207
# 558648    yv1lz56d7y2720819
# 558804    yv4cy982971355864
# Name: vin, Length: 3788, dtype: object

# %%
df['vin'].fillna(value='NoValue',inplace=True)
# Out:
# /var/folders/hm/3hjn5bs11132j0jk91mr7b4r0000gn/T/ipykernel_93710/3538321900.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['vin'].fillna(value='NoValue',inplace=True)

# %%
df['vin'].str.slice(0,3).head(8)
# Out:
# 0    5xy
# 1    5xy
# 2    wba
# 3    yv1
# 4    wba
# 5    1n4
# 6    wbs
# 7    1g1
# Name: vin, dtype: object

# %% [markdown]
# ### Create WMI Mapping
# Builds a dictionary to link WMI codes to valid 'make' values using existing data where 'make' is known
# This approach helps fill in missing car manufacturer names using the WMI code from the VIN.

# %%
# Converts both vin and make to string type to avoid type errors in later operations.

df['vin'] = df['vin'].astype(str)
df['make'] = df['make'].astype(str)

# Extract the WMI (World Manufacturer Identifier)

df['wmi']=df['vin'].str.slice(0,3)

# %%
# Count Initial 'NO_VALUE' Entries in 'make'

initial_no_value_count = df[df['make'] == 'NO_VALUE'].shape[0]
print("Initial NO_VALUE count in 'make':", initial_no_value_count)
# Out:
# Initial NO_VALUE count in 'make': 10301

# %% [markdown]
# ### Build WMI-to-Make Mapping
#
# - Filters the DataFrame to exclude rows where vin is "NoValue" or make is "NO_VALUE".
# - Selects the columns wmi and make.
# - Uses .set_index('wmi')['make'] to convert the DataFrame into a dictionary {wmi: make}.
# - This dictionary (wmi_mapping) allows us to look up the make based on the WMI.

# %%
wmi_mapping = (
    df.loc[(df['vin'] != 'NoValue') & (df['make'] != 'NO_VALUE'), ['wmi', 'make']]
    .set_index('wmi')['make']
    .to_dict()
)

print("Number of valid mappings in WMI_mapping:", len(wmi_mapping))
# Out:
# Number of valid mappings in WMI_mapping: 284

# %%
wmi_mapping
# Out:
# {'5xy': 'KIA',
#  'wba': 'BMW',
#  'yv1': 'VOLVO',
#  '1n4': 'NISSAN',
#  'wbs': 'BMW',
#  '1g1': 'CHEVROLET',
#  'wau': 'AUDI',
#  '2g1': 'CHEVROLET',
#  '5xx': 'KIA',
#  '3fa': 'FORD',
#  '5np': 'HYUNDAI',
#  'wa1': 'AUDI',
#  'yv4': 'VOLVO',
#  '5ux': 'BMW',
#  '1g4': 'BUICK',
#  '1gn': 'CHEVROLET',
#  '1g6': 'CADILLAC',
#  '19v': 'ACURA',
#  'kna': 'KIA',
#  '2t2': 'LEXUS',
#  '3n1': 'NISSAN',
#  '5ga': 'BUICK',
#  'tru': 'AUDI',
#  '1gc': 'CHEVROLET',
#  '5fr': 'ACURA',
#  '3gc': 'CHEVROLET',
#  '3gy': 'CADILLAC',
#  'jn1': 'INFINITI',
#  'jn8': 'NISSAN',
#  'km8': 'HYUNDAI',
#  'kmh': 'HYUNDAI',
#  '1c4': 'JEEP',
#  'wdd': 'MERCEDES-BENZ',
#  'jth': 'LEXUS',
#  'ja4': 'MITSUBISHI',
#  'jm1': 'MAZDA',
#  'knd': 'KIA',
#  '4a4': 'MITSUBISHI',
#  'wmw': 'MINI',
#  'jm3': 'MAZDA',
#  '5n1': 'NISSAN',
#  'jtj': 'LEXUS',
#  'sal': 'LAND ROVER',
#  'wdc': 'MERCEDES-BENZ',
#  '2lm': 'LINCOLN',
#  'saj': 'JAGUAR',
#  '4jg': 'MERCEDES-BENZ',
#  'ja3': 'MITSUBISHI',
# ...

# %%
print("Number of valid mappings in WMI_mapping:", len(wmi_mapping))
# Out:
# Number of valid mappings in WMI_mapping: 284

# %%
def map_make(row):
    if row['make'] == 'NO_VALUE':  # Only update if 'make' is missing
        wmi_value = row['wmi']  
        if wmi_value in wmi_mapping:  # Check if WMI is in mapping
            return wmi_mapping[wmi_value]  # Replace with mapped value
    return row['make']

# %%
df['make'] = df.apply(map_make, axis=1)

# %%
updated_no_make_count = df[df['make'] == 'NO_VALUE'].shape[0]
print("NO_VALUE count after update:", updated_no_make_count)
# Out:
# NO_VALUE count after update: 22

# %%
remaining_nan_count = df['make'].isna().sum()
print("Remaining NaN values in 'make':", remaining_nan_count)
# Out:
# Remaining NaN values in 'make': 0

# %%
df.drop(columns=['wmi'], inplace=True)

# %%
df[df['make']=='NO_VALUE']
# Out:
#         year      make model trim body transmission                vin state  \
# 150295  1998  NO_VALUE   NaN  NaN  NaN    automatic  1l1fm81w4wy701356    fl
# 162663  2009  NO_VALUE   NaN  NaN  NaN    automatic  3d2ws28t69g526541    ca
# 167059  2003  NO_VALUE   NaN  NaN  NaN    automatic  1l1fm81w13y674855    ca
# 204439  2006  NO_VALUE   NaN  NaN  NaN    automatic  wdypd744x65871254    oh
# 253180  2006  NO_VALUE   NaN  NaN  NaN    automatic  wdypd644365880579    pa
# 275143  2007  NO_VALUE   NaN  NaN  NaN    automatic  4gldv13w37d203460    pa
# 281625  1985  NO_VALUE   NaN  NaN  NaN       manual  1jccf87exft014425    ca
# 313103  1999  NO_VALUE   NaN  NaN  NaN    automatic  1l1fm81w1xy707715    fl
# 332097  2013  NO_VALUE   NaN  NaN  NaN    automatic  wdapf3cc4d9552920    ca
# 332101  2013  NO_VALUE   NaN  NaN  NaN    automatic  wdapf3cc5d9552697    ca
# 332102  2013  NO_VALUE   NaN  NaN  NaN    automatic  wdapf3cc1d9553085    ca
# ...

# %%
df=df.drop(df[df['make']=='NO_VALUE'].index)

# %%
df.shape
# Out:
# (558815, 16)

# %%
df.isnull().sum()
# Out:
# year                0
# make                0
# model           10377
# trim            10629
# body            13173
# transmission    65351
# vin                 0
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df.fillna({'model':'no_model'},inplace=True)

# %%
df[df['model']=='no_model']
# Out:
#         year        make     model   trim   body transmission  \
# 72      2014         BMW  no_model  750Li  Sedan    automatic
# 742     2012         BMW  no_model    NaN    NaN    automatic
# 747     2012         BMW  no_model    NaN    NaN    automatic
# 766     2012         BMW  no_model    NaN    NaN    automatic
# 798     2012         BMW  no_model    NaN    NaN    automatic
# ...      ...         ...       ...    ...    ...          ...
# 558545  2000      NISSAN  no_model    NaN    NaN    automatic
# 558617  2007       LEXUS  no_model    NaN    NaN    automatic
# 558736  2011  MITSUBISHI  no_model    NaN    NaN    automatic
# 558773  2005   CHEVROLET  no_model    NaN    NaN    automatic
# 558776  2013    MASERATI  no_model    NaN    NaN    automatic
#
#                       vin state  condition  odometer      color interior  \
# 72      wbaye8c59ed134514    ca       43.0   12172.0      black    black
# ...

# %% [markdown]
# ### Extract VDS
# The 4th to 8th characters of the VIN are stored in a new column called 'vds'.
#
# ### Create VDS Mapping
# Builds a dictionary to link VDS codes to valid 'model' and 'trim' values using existing data where 'model' and 'trim' is known. This approach helps fill in missing car model and trim names using the VDS code from the VIN.

# %%
df['vin'] = df['vin'].astype(str)
df['model'] = df['model'].astype(str)

df['vds'] = df['vin'].str.slice(3, 8)


initial_no_model_count = df[df['model'] == 'no_model'].shape[0]
print("Initial NO_MODEL count in 'model':", initial_no_model_count)

vds_mapping = (
    df.loc[(df['vin'] != 'NoValue') & (df['model'] != 'no_model'), ['vds', 'model']]
    .set_index('vds')['model']
    .to_dict()
)

print("Number of valid mappings in vds_mapping:", len(vds_mapping))

def map_make(row):
    if row['model'] == 'no_model':
        vds_value = row['vds']  
        if vds_value in vds_mapping:
            return vds_mapping[vds_value]
    return row['model']


df['model'] = df.apply(map_make, axis=1)


updated_no_model_count = df[df['model'] == 'no_model'].shape[0]
print("NO_MODEL count after update:", updated_no_model_count)


remaining_nan_count = df['model'].isna().sum()
print("Remaining NaN values in 'model':", remaining_nan_count)


df.drop(columns=['vds'], inplace=True)
# Out:
# Initial NO_MODEL count in 'model': 10377
# Number of valid mappings in vds_mapping: 9380
# NO_MODEL count after update: 588
# Remaining NaN values in 'model': 0

# %%
df[df['model']=='no_model']
# Out:
#         year        make     model trim body transmission                vin  \
# 2082    2011        FORD  no_model  NaN  NaN    automatic  1ftlr1fe5bpa06821
# 5274    1989   CHEVROLET  no_model  NaN  NaN    automatic  1gccs14z3k8155622
# 14332   2009     PONTIAC  no_model  NaN  NaN       manual  5y2sn67099z434736
# 14343   2009     PONTIAC  no_model  NaN  NaN          NaN  1g2ar55h097235724
# 21593   2006  VOLKSWAGEN  no_model  NaN  NaN    automatic  3vwft71k06m849977
# ...      ...         ...       ...  ...  ...          ...                ...
# 555993  2008   CHEVROLET  no_model  NaN  NaN       manual  3gnca33d68s722532
# 556039  2008        JEEP  no_model  NaN  NaN    automatic  1j4fz24108l653866
# 556338  2004       HONDA  no_model  NaN  NaN    automatic  1hgen26574l000508
# 557855  2000        JEEP  no_model  NaN  NaN    automatic  1j4g248n0yc134219
# 558776  2013    MASERATI  no_model  NaN  NaN    automatic  zam39nka2d0068288
#
# ...

# %%
df=df.drop(df[df['model']=='no_model'].index)

# %%
df.isnull().sum()
# Out:
# year                0
# make                0
# model               0
# trim            10053
# body            12597
# transmission    65123
# vin                 0
# state               0
# condition       11809
# odometer           93
# color             747
# interior          747
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df['trim']=df['trim'].str.upper()
df['trim'].nunique()
# Out:
# 1887

# %%
df['vin'][df['trim']=='LX']
# Out:
# 0         5xyktca69fg566472
# 1         5xyktca69fg561319
# 11        5xxgm4a73fg353538
# 13        5xyktca66fg561407
# 32        5xyktca60fg565226
#                 ...
# 558527    19xfb2f50ce358150
# 558574    kndmg4c71b6368197
# 558654    2hgfb2f59eh556606
# 558684    kndmg4c74b6402312
# 558796    1c3ccbab2dn734510
# Name: vin, Length: 20782, dtype: object

# %%
df['trim'].fillna('no_trim',inplace=True)
# Out:
# /var/folders/hm/3hjn5bs11132j0jk91mr7b4r0000gn/T/ipykernel_93710/4210175334.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['trim'].fillna('no_trim',inplace=True)

# %%
df['vin'] = df['vin'].astype(str)
df['trim'] = df['trim'].astype(str)

df['vds'] = df['vin'].str.slice(3, 8)

# %%
initial_no_trim_count = df[df['trim'] == 'no_trim'].shape[0]
print("Initial NO_TRIM count in 'trim':", initial_no_trim_count)
# Out:
# Initial NO_TRIM count in 'trim': 10053

# %%
vds_trim = (
    df.loc[(df['vin'] != 'NoValue') & (df['trim'] != 'no_trim'), ['vds', 'trim']]
    .set_index('vds')['trim']
    .to_dict()
)

print("Number of valid mappings in vds_trim:", len(vds_trim))
# Out:
# Number of valid mappings in vds_trim: 9350

# %%
def map_make(row):
    if row['trim'] == 'no_trim':
        vds_value = row['vds']  
        if vds_value in vds_trim:
            return vds_trim[vds_value]
    return row['trim']


df['trim'] = df.apply(map_make, axis=1)


updated_no_trim_count = df[df['trim'] == 'no_trim'].shape[0]
print("NO_TRIM count after update:", updated_no_trim_count)


remaining_nan_count = df['trim'].isna().sum()
print("Remaining NaN values in 'trim':", remaining_nan_count)
# Out:
# NO_TRIM count after update: 462
# Remaining NaN values in 'trim': 0

# %%
df.drop(columns=['vds'], inplace=True)

# %%
df[df['trim']=='no_trim']
# Out:
#         year       make     model     trim body transmission  \
# 3378    2007  CHEVROLET  CORVETTE  no_trim  NaN    automatic
# 3395    2007  CHEVROLET  CORVETTE  no_trim  NaN    automatic
# 3908    2006      MAZDA       RX8  no_trim  NaN       manual
# 4445    2004      MAZDA       RX8  no_trim  NaN       manual
# 4500    2004      MAZDA       RX8  no_trim  NaN    automatic
# ...      ...        ...       ...      ...  ...          ...
# 557206  2005  CHEVROLET  CORVETTE  no_trim  NaN       manual
# 557252  2004      MAZDA       RX8  no_trim  NaN    automatic
# 558166  2005  CHEVROLET  CORVETTE  no_trim  NaN       manual
# 558167  2005  CHEVROLET  CORVETTE  no_trim  NaN       manual
# 558773  2005  CHEVROLET  CORVETTE  no_trim  NaN    automatic
#
#                       vin state  condition  odometer     color interior  \
# 3378    1g1yy26u575103115    ca       41.0   55299.0     black    black
# 3395    1g1yy26u075116869    ca       36.0   56923.0     black    black
# ...

# %%
df=df.drop(df[df['trim']=='no_trim'].index)

# %%
df['body'].unique()
# Out:
# array(['SUV', 'Sedan', 'Convertible', 'Coupe', 'Wagon', 'Hatchback',
#        'Crew Cab', 'G Coupe', 'G Sedan', 'Elantra Coupe', 'Genesis Coupe',
#        'Minivan', nan, 'Van', 'Double Cab', 'CrewMax Cab', 'Access Cab',
#        'King Cab', 'SuperCrew', 'CTS Coupe', 'Extended Cab',
#        'E-Series Van', 'SuperCab', 'Regular Cab', 'G Convertible', 'Koup',
#        'Quad Cab', 'CTS-V Coupe', 'sedan', 'G37 Convertible', 'Club Cab',
#        'Xtracab', 'Q60 Convertible', 'CTS Wagon', 'convertible',
#        'G37 Coupe', 'Mega Cab', 'Cab Plus 4', 'Q60 Coupe', 'Cab Plus',
#        'Beetle Convertible', 'TSX Sport Wagon', 'Promaster Cargo Van',
#        'GranTurismo Convertible', 'CTS-V Wagon', 'Ram Van', 'minivan',
#        'suv', 'Transit Van', 'Navitgation', 'van', 'regular-cab',
#        'g sedan', 'g coupe', 'hatchback', 'king cab', 'supercrew',
#        'g convertible', 'coupe', 'crew cab', 'wagon', 'double cab',
# ...

# %%
df['body']=df['body'].str.upper()
df['body'].nunique()
# Out:
# 46

# %%
df['body'].fillna('no_body',inplace=True)
# Out:
# /var/folders/hm/3hjn5bs11132j0jk91mr7b4r0000gn/T/ipykernel_93710/1576458170.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['body'].fillna('no_body',inplace=True)

# %% [markdown]
# ### Extract VDS Segment
# The 5th character of the VIN is stored in a new column called 'vds'.
#
# ### Create VDS-Body Mapping
# Builds a dictionary to link VDS codes to valid 'body' values using existing data where 'body' is known This approach helps fill in missing car body types using a character from the VDS code in the VIN.

# %%
df['vin'] = df['vin'].astype(str)
df['body'] = df['body'].astype(str)

df['vds'] = df['vin'].str.slice(4, 5)


initial_no_body_count = df[df['body'] == 'no_body'].shape[0]
print("Initial NO_BODY count in 'body':", initial_no_body_count)

vds_body = (
    df.loc[(df['vin'] != 'NoValue') & (df['body'] != 'no_body'), ['vds', 'body']]
    .set_index('vds')['body']
    .to_dict()
)

print("Number of valid mappings in vds_body:", len(vds_body))

def map_make(row):
    if row['body'] == 'no_body':
        vds_value = row['vds']  
        if vds_value in vds_body:
            return vds_body[vds_value]
    return row['body']


df['body'] = df.apply(map_make, axis=1)


updated_no_body_count = df[df['body'] == 'no_body'].shape[0]
print("NO_BODY count after update:", updated_no_body_count)


remaining_nan_count = df['body'].isna().sum()
print("Remaining NaN values in 'body':", remaining_nan_count)


df.drop(columns=['vds'], inplace=True)
# Out:
# Initial NO_BODY count in 'body': 12135
# Number of valid mappings in vds_body: 33
# NO_BODY count after update: 0
# Remaining NaN values in 'body': 0

# %%
df.transmission.nunique()
# Out:
# 4

# %%
df.transmission=df.transmission.str.upper()
df.transmission.nunique()
# Out:
# 3

# %%
df['transmission'].fillna('no_transmission',inplace=True)
# Out:
# /var/folders/hm/3hjn5bs11132j0jk91mr7b4r0000gn/T/ipykernel_93710/4140762993.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['transmission'].fillna('no_transmission',inplace=True)

# %% [markdown]
# ### Extract VDS Segment
# The 7th character of the VIN is stored in a new column called 'vds'.
#
# ### Create VDS-Transmission Mapping
# Builds a dictionary to link VDS codes to valid 'transmission' values using existing data where 'transmission' is known. This approach helps fill in missing transmission types using a character from the VDS code in the VIN.

# %%
df['vin'] = df['vin'].astype(str)
df['transmission'] = df['transmission'].astype(str)

df['vds'] = df['vin'].str.slice(6, 7)


initial_no_transmission_count = df[df['transmission'] == 'no_transmission'].shape[0]
print("Initial no_transmission count in 'body':", initial_no_transmission_count)

vds_transmission = (
    df.loc[(df['vin'] != 'NoValue') & (df['transmission'] != 'no_transmission'), ['vds', 'transmission']]
    .set_index('vds')['transmission']
    .to_dict()
)

print("Number of valid mappings in vds_transmission:", len(vds_transmission))

def map_make(row):
    if row['transmission'] == 'no_transmission':
        vds_value = row['vds']  
        if vds_value in vds_transmission:
            return vds_transmission[vds_value]
    return row['transmission']


df['transmission'] = df.apply(map_make, axis=1)


updated_no_transmission_count = df[df['transmission'] == 'no_transmission'].shape[0]
print("no_transmission count after update:", updated_no_transmission_count)


remaining_nan_count = df['transmission'].isna().sum()
print("Remaining NaN values in 'transmission':", remaining_nan_count)


df.drop(columns=['vds'], inplace=True)
# Out:
# Initial no_transmission count in 'body': 65052
# Number of valid mappings in vds_transmission: 33
# no_transmission count after update: 0
# Remaining NaN values in 'transmission': 0

# %%
df[df['condition'].isna()].groupby('make').size()
# Out:
# make
# ACURA             169
# AUDI              138
# BENTLEY             1
# BMW               414
# BUICK             175
# CADILLAC          282
# CHEV TRUCK          1
# CHEVROLET        1387
# CHRYSLER          385
# DAEWOO              1
# DODGE             659
# FIAT                8
# FORD             1560
# GMC               299
# GMC TRUCK           5
# HONDA             862
# HUMMER             19
# HYUNDAI           341
# HYUNDAI TK          1
# INFINITI          126
# ISUZU              16
# JAGUAR             43
# JEEP              387
# KIA               205
# LAND ROVER         52
# LANDROVER           1
# LEXUS             201
# LINCOLN           122
# MASERATI            2
# MAZDA             209
# MAZDA TK            1
# MERCEDES           11
# MERCEDES-B          1
# MERCEDES-BENZ     353
# MERCURY           105
# MINI               50
# MITSUBISHI        114
# NISSAN            833
# OLDSMOBILE         34
# PLYMOUTH            6
# PONTIAC           260
# ...

# %%
df['condition'][df['make']=='BMW']
# Out:
# 2         45.0
# 4         43.0
# 6         34.0
# 19        34.0
# 21        29.0
#           ...
# 558781    25.0
# 558783    37.0
# 558808    33.0
# 558831    39.0
# 558834    48.0
# Name: condition, Length: 21257, dtype: float64

# %%
df['condition'].unique()
# Out:
# array([ 5., 45., 41., 43.,  1., 34.,  2., 42.,  3., 48., nan, 49., 17.,
#        19., 29., 38., 44., 47., 32.,  4., 25., 37., 39., 31., 28., 46.,
#        36., 35., 26., 21., 22., 27., 24., 33., 23., 15., 16., 18., 12.,
#        14., 11., 13.])

# %%
df['condition']=df['condition']/10
df['condition']
# Out:
# 0         0.5
# 1         0.5
# 2         4.5
# 3         4.1
# 4         4.3
#          ...
# 558832    4.5
# 558833    0.5
# 558834    4.8
# 558835    3.8
# 558836    3.4
# Name: condition, Length: 557765, dtype: float64

# %%
df['condition'] = pd.to_numeric(df['condition'], errors='coerce')

def replace(row):
    if row['condition'] == 5.0:
      return 'Excellent'
    elif (row['condition'] <= 4.9) and (row['condition'] >= 4.0):
        return 'Good'
    elif (row['condition'] <= 3.9) and (row['condition'] >= 3.0):
        return 'Fair'
    elif (row['condition'] <= 2.9) and (row['condition'] >= 2.0):
        return 'Poor'
    elif row['condition'] < 2.0:
        return 'Needs major maintenance'
    else :
        return row['condition']


df['condition']=df.apply(replace, axis=1)

# %%
df['condition'].fillna('no_condition',inplace=True)
# Out:
# /var/folders/hm/3hjn5bs11132j0jk91mr7b4r0000gn/T/ipykernel_93710/368469979.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['condition'].fillna('no_condition',inplace=True)

# %%
pivot_table=df.pivot_table(index='condition',values='sellingprice',aggfunc='max')
pivot_table
# Out:
#                          sellingprice
# condition
# Fair                         169000.0
# Good                         230000.0
# Needs major maintenance      165000.0
# Poor                         117000.0
# no_condition                 112000.0

# %%
df = df.dropna(subset=['sellingprice'])

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    KIA              SORENTO          LX    SUV    AUTOMATIC
# 1  2015    KIA              SORENTO          LX    SUV    AUTOMATIC
# 2  2014    BMW             3 SERIES  328I SULEV  SEDAN    AUTOMATIC
# 3  2015  VOLVO                  S60          T5  SEDAN    AUTOMATIC
# 4  2014    BMW  6 SERIES GRAN COUPE        650I  SEDAN    AUTOMATIC
#
#                  vin state                condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca  Needs major maintenance   16639.0  white    black
# 1  5xyktca69fg561319    ca  Needs major maintenance    9393.0  white    beige
# 2  wba3c1c51ek116351    ca                     Good    1331.0   gray    black
# 3  yv1612tb4f1310987    ca                     Good   14282.0  white    black
# 4  wba6b2c57ed129731    ca                     Good    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# ...

# %%
def impute_condition(row):
    if (row['condition']=='no_condition'):
        if row['sellingprice'] > 169000.0:
            return 'Good'
        elif row['sellingprice'] <= 169000.0 and row['sellingprice']>165000.0:
            return 'Fair'
        elif (row['sellingprice'] <= 165000.0) and (row['sellingprice']>=117000.0):
            return 'Poor'
        else:
            return 'Needs major maintenance'
    return row['condition']

df['condition'] = df.apply(impute_condition, axis=1)

# %%
df.isnull().sum()
# Out:
# year              0
# make              0
# model             0
# trim              0
# body              0
# transmission      0
# vin               0
# state             0
# condition         0
# odometer         93
# color           747
# interior        747
# seller            0
# mmr              26
# sellingprice      0
# saledate          0
# dtype: int64

# %%
outliers={}
df['odometer'] = pd.to_numeric(df['odometer'], errors='coerce')
numerical_cols = ['odometer','mmr']
for col in numerical_cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers[col] = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
    print(f"\nOutliers in {col}:\n", outliers[col])
# Out:
# Outliers in odometer:
#  275       999999.0
# 1666      227606.0
# 2038      236928.0
# 2470      291087.0
# 2682      237880.0
#             ...
# 558465    241787.0
# 558468    209889.0
# 558470    215038.0
# 558717    220815.0
# 558791    262065.0
# Name: odometer, Length: 10345, dtype: float64
#
# Outliers in mmr:
#  4          66000.0
# 6          69000.0
# 10         47300.0
# 17         37100.0
# 19         68000.0
#             ...
# 558777     53300.0
# 558807     64000.0
# 558816    104000.0
# 558824     43900.0
# 558832     35300.0
# Name: mmr, Length: 16506, dtype: float64

# %%
df['odometer'].fillna(df['odometer'].median(),inplace=True)
# Out:
# /var/folders/hm/3hjn5bs11132j0jk91mr7b4r0000gn/T/ipykernel_93710/3946100476.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['odometer'].fillna(df['odometer'].median(),inplace=True)

# %%
df['mmr'].fillna(df['mmr'].median(),inplace=True)
# Out:
# /var/folders/hm/3hjn5bs11132j0jk91mr7b4r0000gn/T/ipykernel_93710/3560066656.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['mmr'].fillna(df['mmr'].median(),inplace=True)

# %%
df['color'].fillna(df['color'].mode()[0],inplace=True)
# Out:
# /var/folders/hm/3hjn5bs11132j0jk91mr7b4r0000gn/T/ipykernel_93710/562916744.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['color'].fillna(df['color'].mode()[0],inplace=True)

# %%
df['interior'].fillna(df['interior'].mode()[0],inplace=True)
# Out:
# /var/folders/hm/3hjn5bs11132j0jk91mr7b4r0000gn/T/ipykernel_93710/1296844938.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['interior'].fillna(df['interior'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
df.groupby('model')['year'].sum()
# Out:
# model
# 1               2011
# 1 SERIES      814412
# 1500         6728867
# 190-CLASS       5979
# 2 SERIES       64461
#               ...
# Z3            121967
# Z4            554549
# Z4 M           10035
# ZDX            78436
# ZEPHYR        190570
# Name: year, Length: 842, dtype: int64

# %%
print(f'Average of price is : {df.sellingprice.mean()}')
print(f'Maximum price is : {df.sellingprice.max()}')
print(f'Minimum price is : {df.sellingprice.min()}')
# Out:
# Average of price is : 13621.773907087905
# Maximum price is : 230000.0
# Minimum price is : 1.0

# %% [markdown]
# ### Data Visualization

# %%
numerical_cols=[
    'year',
    'odometer',
    'mmr',
    'sellingprice'
]

# %%
plt.figure(figsize=(10,5))
corr_matrix=df[numerical_cols].corr()
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
fig, axs = plt.subplots(4, 1, dpi=95, figsize=(10, 8))

for i, col in enumerate(numerical_cols):  
    axs[i].boxplot(df[col], vert=False, patch_artist=True, boxprops=dict(facecolor='#00ced1'))  
    axs[i].set_ylabel(col)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 6))
values = df['transmission'].value_counts() 
plt.pie(values, labels=values.index, autopct='%.1f%%', shadow=True)
plt.title('transnission Proportionality')
plt.show()

# %%
plt.figure(figsize=(6, 6))
values = df['condition'].value_counts() 
plt.pie(values, labels=values.index, autopct='%.1f%%', shadow=True)
plt.title('condition Proportionality')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(x=df['year'], color="blue")
plt.show()

# %%
plt.figure(figsize=(40,20))
sns.histplot(x=df['make'], color="blue")
plt.show()

# %%
df['model_code'] = df['model'].astype('category').cat.codes
df['make_code'] = df['make'].astype('category').cat.codes
df['trim_code'] = df['trim'].astype('category').cat.codes
df['transmission_code']=df['transmission'].astype('category').cat.codes
df['body_code'] = df['body'].astype('category').cat.codes


kwargs = dict(histtype='stepfilled', alpha=0.5, density=True, bins=40)
fig, axs = plt.subplots(1, 6, figsize=(18, 8))

axs[0].hist(df['model_code'], **kwargs, color='blue')
axs[0].set_title('Distribution of Car Models', fontsize=14)
axs[0].set_xlabel('Model', fontsize=12)
axs[0].set_ylabel('Density', fontsize=12)
                 
axs[1].hist(df['year'], **kwargs, color='green')
axs[1].set_title('Distribution of Car Years', fontsize=14)
axs[1].set_xlabel('Year', fontsize=12)
axs[1].set_ylabel('Density', fontsize=12)

axs[2].hist(df['make_code'], **kwargs, color='red')
axs[2].set_title('Distribution of Car Make', fontsize=14)
axs[2].set_xlabel('Make', fontsize=12)
axs[2].set_ylabel('Density', fontsize=12)

axs[3].hist(df['trim_code'], **kwargs, color='darkorange')
axs[3].set_title('Distribution of Car Trim', fontsize=14)
axs[3].set_xlabel('Trim', fontsize=12)
axs[3].set_ylabel('Density', fontsize=12)

axs[4].hist(df['transmission_code'], **kwargs, color='purple')
axs[4].set_title('Distribution of Car Transmission', fontsize=14)
axs[4].set_xlabel('Transmission', fontsize=12)
axs[4].set_ylabel('Density', fontsize=12)

axs[5].hist(df['body_code'], **kwargs, color='teal')
axs[5].set_title('Distribution of Car Body', fontsize=14)
axs[5].set_xlabel('Body', fontsize=12)
axs[5].set_ylabel('Density', fontsize=12)

plt.tight_layout()
plt.show()
